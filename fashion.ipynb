# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
import numpy as np
import matplotlib.pyplot as plt

# Load Fashion MNIST dataset
fashion_mnist = keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize the dataset
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape data to add channel dimension
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Function to create a CNN model
def create_model(filter_size=3, regularization=0.001, optimizer='adam'):
    model = keras.Sequential([
        layers.Conv2D(32, (filter_size, filter_size), activation='relu', kernel_regularizer=regularizers.l2(regularization), input_shape=(28, 28, 1)),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (filter_size, filter_size), activation='relu', kernel_regularizer=regularizers.l2(regularization)),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(regularization)),
        layers.Dense(10, activation='softmax')
    ])
    
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Experiment with different configurations
filter_sizes = [3, 5]
regularizations = [0.0001, 0.001]
batch_sizes = [32, 64]
optimizers = ['adam', 'sgd']

results = {}

for filter_size in filter_sizes:
    for regularization in regularizations:
        for batch_size in batch_sizes:
            for optimizer in optimizers:
                key = f"Filter={filter_size}, Reg={regularization}, Batch={batch_size}, Opt={optimizer}"
                print(f"Training with {key}")
                model = create_model(filter_size, regularization, optimizer)
                history = model.fit(x_train, y_train, epochs=5, batch_size=batch_size, validation_data=(x_test, y_test), verbose=2)
                test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
                results[key] = history
                print(f"Test accuracy: {test_acc:.4f}\n")

# Plotting results
plt.figure(figsize=(12, 8))
for key, history in results.items():
    plt.plot(history.history['val_accuracy'], label=key)
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.title('Effect of Hyperparameters on Model Performance')
plt.legend()
plt.show()
# Out:
# Training with Filter=3, Reg=0.0001, Batch=32, Opt=adam
# Epoch 1/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.8354 - loss: 0.4856 - val_accuracy: 0.8749 - val_loss: 0.3885
# Epoch 2/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.8863 - loss: 0.3516 - val_accuracy: 0.8849 - val_loss: 0.3525
# Epoch 3/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9013 - loss: 0.3164 - val_accuracy: 0.8956 - val_loss: 0.3328
# Epoch 4/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9105 - loss: 0.2936 - val_accuracy: 0.9046 - val_loss: 0.3156
# Epoch 5/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9164 - loss: 0.2771 - val_accuracy: 0.8980 - val_loss: 0.3296
# Test accuracy: 0.8980
#
# Training with Filter=3, Reg=0.0001, Batch=32, Opt=sgd
# Epoch 1/5
# 1875/1875 - 14s - 7ms/step - accuracy: 0.6791 - loss: 0.9246 - val_accuracy: 0.7501 - val_loss: 0.6560
# Epoch 2/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.7999 - loss: 0.5652 - val_accuracy: 0.8275 - val_loss: 0.5195
# Epoch 3/5
# 1875/1875 - 14s - 8ms/step - accuracy: 0.8349 - loss: 0.4844 - val_accuracy: 0.8361 - val_loss: 0.4840
# Epoch 4/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.8521 - loss: 0.4421 - val_accuracy: 0.8481 - val_loss: 0.4532
# Epoch 5/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8615 - loss: 0.4145 - val_accuracy: 0.8601 - val_loss: 0.4264
# Test accuracy: 0.8601
#
# Training with Filter=3, Reg=0.0001, Batch=64, Opt=adam
# Epoch 1/5
# 938/938 - 11s - 12ms/step - accuracy: 0.8245 - loss: 0.5155 - val_accuracy: 0.8683 - val_loss: 0.3996
# Epoch 2/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8828 - loss: 0.3607 - val_accuracy: 0.8847 - val_loss: 0.3542
# Epoch 3/5
# 938/938 - 10s - 10ms/step - accuracy: 0.8967 - loss: 0.3199 - val_accuracy: 0.8911 - val_loss: 0.3416
# Epoch 4/5
# 938/938 - 10s - 11ms/step - accuracy: 0.9060 - loss: 0.2977 - val_accuracy: 0.8973 - val_loss: 0.3166
# Epoch 5/5
# 938/938 - 189s - 202ms/step - accuracy: 0.9136 - loss: 0.2782 - val_accuracy: 0.8995 - val_loss: 0.3181
# Test accuracy: 0.8995
#
# Training with Filter=3, Reg=0.0001, Batch=64, Opt=sgd
# Epoch 1/5
# 938/938 - 10s - 10ms/step - accuracy: 0.6364 - loss: 1.0855 - val_accuracy: 0.7004 - val_loss: 0.8475
# Epoch 2/5
# 938/938 - 9s - 10ms/step - accuracy: 0.7685 - loss: 0.6529 - val_accuracy: 0.7815 - val_loss: 0.6232
# Epoch 3/5
# 938/938 - 9s - 10ms/step - accuracy: 0.8005 - loss: 0.5647 - val_accuracy: 0.7818 - val_loss: 0.6039
# Epoch 4/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8219 - loss: 0.5189 - val_accuracy: 0.8104 - val_loss: 0.5368
# Epoch 5/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8338 - loss: 0.4875 - val_accuracy: 0.8263 - val_loss: 0.5057
# Test accuracy: 0.8263
#
# Training with Filter=3, Reg=0.001, Batch=32, Opt=adam
# Epoch 1/5
# 1875/1875 - 17s - 9ms/step - accuracy: 0.8277 - loss: 0.6186 - val_accuracy: 0.8553 - val_loss: 0.5129
# Epoch 2/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.8696 - loss: 0.4600 - val_accuracy: 0.8587 - val_loss: 0.4850
# Epoch 3/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8810 - loss: 0.4273 - val_accuracy: 0.8741 - val_loss: 0.4404
# Epoch 4/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.8858 - loss: 0.4072 - val_accuracy: 0.8814 - val_loss: 0.4133
# Epoch 5/5
# 1875/1875 - 17s - 9ms/step - accuracy: 0.8916 - loss: 0.3908 - val_accuracy: 0.8853 - val_loss: 0.4060
# Test accuracy: 0.8853
#
# Training with Filter=3, Reg=0.001, Batch=32, Opt=sgd
# Epoch 1/5
# 1875/1875 - 14s - 8ms/step - accuracy: 0.6817 - loss: 1.1641 - val_accuracy: 0.7761 - val_loss: 0.8741
# Epoch 2/5
# 1875/1875 - 14s - 8ms/step - accuracy: 0.8011 - loss: 0.8019 - val_accuracy: 0.8159 - val_loss: 0.7632
# Epoch 3/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8321 - loss: 0.7149 - val_accuracy: 0.8402 - val_loss: 0.6917
# Epoch 4/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8479 - loss: 0.6614 - val_accuracy: 0.8500 - val_loss: 0.6522
# Epoch 5/5
# 1875/1875 - 92s - 49ms/step - accuracy: 0.8579 - loss: 0.6212 - val_accuracy: 0.8488 - val_loss: 0.6352
# Test accuracy: 0.8488
#
# Training with Filter=3, Reg=0.001, Batch=64, Opt=adam
# Epoch 1/5
# 938/938 - 14s - 15ms/step - accuracy: 0.8169 - loss: 0.6625 - val_accuracy: 0.8475 - val_loss: 0.5443
# Epoch 2/5
# 938/938 - 11s - 12ms/step - accuracy: 0.8674 - loss: 0.4758 - val_accuracy: 0.8643 - val_loss: 0.4774
# Epoch 3/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8794 - loss: 0.4326 - val_accuracy: 0.8798 - val_loss: 0.4283
# Epoch 4/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8861 - loss: 0.4085 - val_accuracy: 0.8764 - val_loss: 0.4323
# Epoch 5/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8899 - loss: 0.3941 - val_accuracy: 0.8845 - val_loss: 0.4140
# Test accuracy: 0.8845
#
# Training with Filter=3, Reg=0.001, Batch=64, Opt=sgd
# Epoch 1/5
# 938/938 - 10s - 11ms/step - accuracy: 0.6235 - loss: 1.3784 - val_accuracy: 0.6563 - val_loss: 1.1867
# Epoch 2/5
# 938/938 - 9s - 10ms/step - accuracy: 0.7650 - loss: 0.9046 - val_accuracy: 0.7313 - val_loss: 0.9328
# Epoch 3/5
# 938/938 - 10s - 10ms/step - accuracy: 0.8014 - loss: 0.8080 - val_accuracy: 0.7994 - val_loss: 0.8002
# Epoch 4/5
# 938/938 - 10s - 10ms/step - accuracy: 0.8224 - loss: 0.7525 - val_accuracy: 0.8140 - val_loss: 0.7653
# Epoch 5/5
# 938/938 - 10s - 10ms/step - accuracy: 0.8364 - loss: 0.7126 - val_accuracy: 0.8374 - val_loss: 0.7171
# Test accuracy: 0.8374
#
# Training with Filter=5, Reg=0.0001, Batch=32, Opt=adam
# Epoch 1/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8374 - loss: 0.4805 - val_accuracy: 0.8707 - val_loss: 0.4017
# Epoch 2/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8903 - loss: 0.3406 - val_accuracy: 0.8918 - val_loss: 0.3362
# Epoch 3/5
# 1875/1875 - 17s - 9ms/step - accuracy: 0.9036 - loss: 0.3076 - val_accuracy: 0.8935 - val_loss: 0.3424
# Epoch 4/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9122 - loss: 0.2877 - val_accuracy: 0.9022 - val_loss: 0.3191
# Epoch 5/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9186 - loss: 0.2720 - val_accuracy: 0.9035 - val_loss: 0.3171
# Test accuracy: 0.9035
#
# Training with Filter=5, Reg=0.0001, Batch=32, Opt=sgd
# Epoch 1/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.7147 - loss: 0.8372 - val_accuracy: 0.7888 - val_loss: 0.5962
# Epoch 2/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8141 - loss: 0.5410 - val_accuracy: 0.8232 - val_loss: 0.5208
# Epoch 3/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.8391 - loss: 0.4728 - val_accuracy: 0.8421 - val_loss: 0.4770
# Epoch 4/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.8551 - loss: 0.4325 - val_accuracy: 0.8553 - val_loss: 0.4348
# Epoch 5/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.8663 - loss: 0.4039 - val_accuracy: 0.8547 - val_loss: 0.4245
# Test accuracy: 0.8547
#
# Training with Filter=5, Reg=0.0001, Batch=64, Opt=adam
# Epoch 1/5
# 938/938 - 12s - 13ms/step - accuracy: 0.8206 - loss: 0.5246 - val_accuracy: 0.8666 - val_loss: 0.4036
# Epoch 2/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8834 - loss: 0.3546 - val_accuracy: 0.8897 - val_loss: 0.3399
# Epoch 3/5
# 938/938 - 11s - 11ms/step - accuracy: 0.8986 - loss: 0.3138 - val_accuracy: 0.8946 - val_loss: 0.3325
# Epoch 4/5
# 938/938 - 10s - 11ms/step - accuracy: 0.9077 - loss: 0.2919 - val_accuracy: 0.9006 - val_loss: 0.3176
# Epoch 5/5
# 938/938 - 10s - 11ms/step - accuracy: 0.9141 - loss: 0.2729 - val_accuracy: 0.8892 - val_loss: 0.3536
# Test accuracy: 0.8892
#
# Training with Filter=5, Reg=0.0001, Batch=64, Opt=sgd
# Epoch 1/5
# 938/938 - 10s - 11ms/step - accuracy: 0.6385 - loss: 1.0549 - val_accuracy: 0.7223 - val_loss: 0.7374
# Epoch 2/5
# 938/938 - 10s - 10ms/step - accuracy: 0.7721 - loss: 0.6403 - val_accuracy: 0.7820 - val_loss: 0.6078
# Epoch 3/5
# 938/938 - 9s - 10ms/step - accuracy: 0.8074 - loss: 0.5551 - val_accuracy: 0.7878 - val_loss: 0.5899
# Epoch 4/5
# 938/938 - 10s - 11ms/step - accuracy: 0.8275 - loss: 0.5088 - val_accuracy: 0.8140 - val_loss: 0.5415
# Epoch 5/5
# 938/938 - 10s - 10ms/step - accuracy: 0.8408 - loss: 0.4751 - val_accuracy: 0.8281 - val_loss: 0.5096
# Test accuracy: 0.8281
#
# Training with Filter=5, Reg=0.001, Batch=32, Opt=adam
# Epoch 1/5
# 1875/1875 - 17s - 9ms/step - accuracy: 0.8267 - loss: 0.6212 - val_accuracy: 0.8452 - val_loss: 0.5281
# Epoch 2/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.8764 - loss: 0.4495 - val_accuracy: 0.8770 - val_loss: 0.4460
# Epoch 3/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8845 - loss: 0.4185 - val_accuracy: 0.8841 - val_loss: 0.4196
# Epoch 4/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.8918 - loss: 0.3967 - val_accuracy: 0.8913 - val_loss: 0.4078
# Epoch 5/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.8964 - loss: 0.3842 - val_accuracy: 0.8949 - val_loss: 0.3887
# Test accuracy: 0.8949
#
# Training with Filter=5, Reg=0.001, Batch=32, Opt=sgd
# Epoch 1/5
# 1875/1875 - 16s - 9ms/step - accuracy: 0.7018 - loss: 1.1112 - val_accuracy: 0.7789 - val_loss: 0.8615
# Epoch 2/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.8087 - loss: 0.7791 - val_accuracy: 0.8264 - val_loss: 0.7337
# Epoch 3/5
# 1875/1875 - 17s - 9ms/step - accuracy: 0.8408 - loss: 0.6930 - val_accuracy: 0.8315 - val_loss: 0.6979
# Epoch 4/5
# 1875/1875 - 17s - 9ms/step - accuracy: 0.8545 - loss: 0.6428 - val_accuracy: 0.8517 - val_loss: 0.6479
# Epoch 5/5
# 1875/1875 - 14s - 8ms/step - accuracy: 0.8634 - loss: 0.6034 - val_accuracy: 0.8460 - val_loss: 0.6387
# Test accuracy: 0.8460
#
# Training with Filter=5, Reg=0.001, Batch=64, Opt=adam
# Epoch 1/5
# 938/938 - 14s - 15ms/step - accuracy: 0.8175 - loss: 0.6616 - val_accuracy: 0.8611 - val_loss: 0.5203
# Epoch 2/5
# 938/938 - 12s - 12ms/step - accuracy: 0.8736 - loss: 0.4654 - val_accuracy: 0.8752 - val_loss: 0.4481
# Epoch 3/5
# 938/938 - 12s - 12ms/step - accuracy: 0.8850 - loss: 0.4174 - val_accuracy: 0.8771 - val_loss: 0.4411
# Epoch 4/5
# 938/938 - 12s - 12ms/step - accuracy: 0.8902 - loss: 0.3980 - val_accuracy: 0.8944 - val_loss: 0.3968
# Epoch 5/5
# 938/938 - 5s - 5ms/step - accuracy: 0.8967 - loss: 0.3794 - val_accuracy: 0.8849 - val_loss: 0.4108
# Test accuracy: 0.8849
#
# Training with Filter=5, Reg=0.001, Batch=64, Opt=sgd
# Epoch 1/5
# 938/938 - 5s - 5ms/step - accuracy: 0.6470 - loss: 1.2844 - val_accuracy: 0.7257 - val_loss: 0.9995
# Epoch 2/5
# 938/938 - 5s - 5ms/step - accuracy: 0.7783 - loss: 0.8642 - val_accuracy: 0.7640 - val_loss: 0.8791
# Epoch 3/5
# 938/938 - 4s - 5ms/step - accuracy: 0.8116 - loss: 0.7790 - val_accuracy: 0.8085 - val_loss: 0.7978
# Epoch 4/5
# 938/938 - 4s - 5ms/step - accuracy: 0.8304 - loss: 0.7266 - val_accuracy: 0.8359 - val_loss: 0.7252
# Epoch 5/5
# 938/938 - 4s - 5ms/step - accuracy: 0.8429 - loss: 0.6885 - val_accuracy: 0.8449 - val_loss: 0.6883
# Test accuracy: 0.8449
